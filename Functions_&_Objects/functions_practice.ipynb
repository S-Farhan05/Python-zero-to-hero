# %%
# my_list = [1,2,4]
# help(my_list.index(2))

# %%
from platform import python_version
print(python_version())
# Out:
# 3.13.7

# %% [markdown]
# Tuple Unpacking with functions

# %%
def employer_of_the_month(empolyer_info:list):

    current_max = 0 
    empolyer_name=''

    for name , hrs in empolyer_info:

        if hrs>current_max:
            current_max=hrs
            empolyer_name=name

    return current_max,empolyer_name

# %%
hrs , name = employer_of_the_month([('Ayesh',180),('hamza',45),('Azan',200),('Faris',150)])
print(name ,f"Hours worked by empolyer: {hrs} ")
# Out:
# Azan Hours worked by empolyer: 200

# %%
from random import shuffle


def shuffle_func(lst:list):
      shuffle(lst)
      return lst


def User_input_func():
    user_input=''
    while user_input not in ['0','1','2']:
         user_input = input("Enter value from 0 to 2 to find hidden thing")
    
    return int(user_input)


def result_checker(lst , input):
     
    if lst[input]=='A':
          print("Congrates u won")

    else:
         print("You lost The correct random position was")
         print(lst)

     

my_list =shuffle_func([' ','A',' '])
user_input = User_input_func()
result_checker(my_list,user_input)
# Out:
# Congrates u won

# %% [markdown]
# *args and **kwargs

# %%
def discount_price(*args):
    print(args)
    print("The original price of ur items were : {} ".format(sum(args)))
    return sum(args)-(sum(args)*0.05)

price = discount_price(100,200,300)
print(f"Discounted price : ",price)




def item_list(**kwargs):
    print(kwargs)
    
    if "food" in kwargs:
     print("The op like {}".format(kwargs['food']))

    else:
       price("no")
    
# we pass keyword argumensta and not a dictioanary
item_list(name="Deed",food="Biryani")
# Out:
# (100, 200, 300)
# The original price of ur items were : 600
# Discounted price :  570.0
# {'name': 'Deed', 'food': 'Biryani'}
# The op like Biryani

# %%
# odd string lower and even upper function pass
def my_func(val):

    new_string = ''
    for i,letter in enumerate(val):
        if i %2==0:
            new_string += letter.upper()

        else:
            new_string += letter.lower()
    return new_string

print(my_func("hahaahhaah"))
# Out:
# HaHaAhHaAh

# %%
# map ,filter and lambda function

def func(name):
    listt =[]
    listt.append(name)
    return listt



names : list = ["Far","Boss","eating"]

print(list(map(func,names)))



def even(lst):
    print(lst)
    if lst%2==0:
        return True
   
my_new_list = [10,12,5,6,7,9]
list(filter(even,my_new_list))




nume = lambda num:num**2
nume(10)


nums = [1,2,3,4,5,6]
print(list(map(lambda idk:idk**2 ,nums)))

list(filter(lambda idk:idk%2 == 0 ,nums))
# Out:
# [['Far'], ['Boss'], ['eating']]
# 10
# 12
# 5
# 6
# 7
# 9
# [1, 4, 9, 16, 25, 36]
# [2, 4, 6]

# %%
def funnn(a):
    print(a)

funnn(12)
# Out:
# 12
