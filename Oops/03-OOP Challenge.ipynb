# %% [markdown]
# # Object Oriented Programming Challenge
#
# For this challenge, create a bank account class that has two attributes:
#
# * owner
# * balance
#
# and two methods:
#
# * deposit
# * withdraw
#
# As an added requirement, withdrawals may not exceed the available balance.
#
# Instantiate your class, make several deposits and withdrawals, and test to make sure the account can't be overdrawn.

# %%
class Account:
    def __init__(self ,name ,balance):

        self.owner = name
        self.balance = balance

    def __str__(self):
        return f"Account owner is -> {self.owner}\nThe current balance is -> {self.balance}rs"
    
    def deposit(self ,amount):
        self.balance = self.balance+amount
        print("{}rs have been added in account".format(amount))
    
    def withdraw(self,amount):

        if self.balance < amount :
            print("Un_Sufficient funds")

        else:
            self.balance =self.balance - amount
            print(f"{amount}rs have been withdrawn ")
            print(f"Current remaining funds are -> {self.balance}rs")

# %%
# 1. Instantiate the class
acct1 = Account('Jose',100)

# %%
# 2. Print the object
print(acct1)
# Out:
# Account owner is -> Jose
# The current balance is -> 100rs

# %%
# 3. Show the account owner attribute
acct1.owner
# Out:
# 'Jose'

# %%
# 4. Show the account balance attribute
acct1.balance
# Out:
# 100

# %%
# 5. Make a series of deposits and withdrawals
acct1.deposit(50)
# Out:
# 50rs have been added in account

# %%
acct1.withdraw(75)
# Out:
# 75rs have been withdrawn
# Current remaining funds are -> 75rs

# %%
# 6. Make a withdrawal that exceeds the available balance
acct1.withdraw(500)
# Out:
# Un_Sufficient funds
